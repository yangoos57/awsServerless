# %% [markdown]
# ### Request Predictions

# %%
import requests
import pandas as pd 
import numpy as np

# %%
payloads = dict(user_search=['파이썬'],selected_lib=['양천'])
resp = requests.post("https://api.yangoos.me/predict", json=payloads)
# resp = requests.post("http://ec2-3-34-99-54.ap-northeast-2.compute.amazonaws.com/predict", json=payloads)
# resp = requests.post("https://b5uvw8vxie.execute-api.ap-northeast-2.amazonaws.com/DoDo-EC2/predict", json=payloads)
# resp =requests.post("http://localhost:8000/predict", json=payloads)
# resp=requests.post("http://127.0.0.1/predict", json=payloads)
# resp=requests.post("http://0.0.0.0/predict", json=payloads)
# resp=requests.post("http://0.0.0.0/test", json=payloads)
resp.text
# Out:
# '{"user_search":["파이썬"],"selected_lib":["양천"],"response":true,"table_id":"0f521ef6-29cc-4709-af59-3a1bc47fe6a3","result":[{"class_no":"005.135","isbn13":"9791162241905","authors":"웨스 맥키니 지음 ;김영근 옮김","bookImageURL":"http://www.hello.world","bookname":"파이썬 라이브러리를 활용한 데이터 분석 :영화 평점, 이름 통계, 선거 데이터 등 실사례 사용 ","publisher":"한빛미디어","reg_date":"2019-05-27","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791158391881","authors":"박재현 지음","bookImageURL":"http://www.hello.world","bookname":"파이썬과 리액트를 활용한 주식 자동거래 시스템 구축","publisher":"위키북스","reg_date":"2020-03-27","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791162242414","authors":"김도형 지음","bookImageURL":"http://www.hello.world","bookname":"김도형의 데이터 사이언스 스쿨 : 수학 편","publisher":"한빛미디어","reg_date":"2020-05-25","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791161753324","authors":"로버트 요한슨 (지은이), (주)크라스랩 (옮긴이)","bookImageURL":"http://www.hello.world","bookname":"파이썬과 수치 해석 2/e - 파이썬 수치 해석 레시피","publisher":"에이콘출판","reg_date":"2019-09-09","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791161752136","authors":"마이클 헤이트 지음 ;이태상 옮김","bookImageURL":"http://www.hello.world","bookname":"Pandas로 하는 데이터 과학 :파이썬 통계 분석 라이브러리 ","publisher":"에이콘","reg_date":"2018-10-10","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791161340210","authors":"이케우치 다카히로,카타야나기 노부코,이와오 엠마 하루카,@driller 지음 ;원인재 옮김","bookImageURL":"http://www.hello.world","bookname":"파이썬 Jupyter Notebook 실전 입문 ","publisher":"터닝포인트","reg_date":"2018-06-08","lib_name":"양천"},{"class_no":"004.73","isbn13":"9788970505220","authors":"박동규,강영민 지음","bookImageURL":"http://www.hello.world","bookname":"(으뜸) 데이터 분석과 머신러닝 ","publisher":"생능출판(생능출판사)","reg_date":"2022-09-19","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791158393571","authors":"최은석 지음","bookImageURL":"http://www.hello.world","bookname":"파이썬 웹 스크레이핑 완벽 가이드 - 파이썬 기초 문법부터 스트림릿을 이용한 웹 앱 제작과 카카오 API 활용까지","publisher":"위키북스","reg_date":"2022-11-18","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791162245569","authors":"포스코인재창조원","bookImageURL":"http://www.hello.world","bookname":"일잘러의 비밀, 엑셀 대신 파이썬으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, 파이썬으로 칼퇴하자!)","publisher":"한빛미디어","reg_date":"2022-05-13","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791158392260","authors":"최은석 지음","bookImageURL":"http://www.hello.world","bookname":"(일 잘하는 직장인을 위한) 엑셀 자동화 with 파이썬 :복잡하고 지루한 반복 업무를 쉽고 빠르게 해치우는 방법 ","publisher":"위키북스","reg_date":"2020-11-30","lib_name":"양천"},{"class_no":"005.133","isbn13":"9788909542111","authors":"아리스티데스 보우라스.루키아 아이나로지두 지음, 이병재 옮김","bookImageURL":"http://www.hello.world","bookname":"10대를 위한 파이썬 교과서","publisher":"교학사(컴퓨터)","reg_date":"2020-02-20","lib_name":"양천"},{"class_no":"004.73","isbn13":"9791162242827","authors":"이시카와 아키히코 지음, 박광수 옮김","bookImageURL":"http://www.hello.world","bookname":"파이썬으로 배우는 딥러닝 교과서","publisher":"한빛미디어","reg_date":"2020-05-14","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791162244210","authors":"미샤 고렐릭,이안 오스발트 지음;오현석 옮김","bookImageURL":"http://www.hello.world","bookname":"고성능 파이썬:파이썬 성능 잠재력을 끌어내는 실용적인 개발 전략서","publisher":"한빛미디어","reg_date":"2021-05-18","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791162245170","authors":"이브 힐피시","bookImageURL":"http://www.hello.world","bookname":"파이썬을 활용한 금융 분석","publisher":"한빛미디어","reg_date":"2022-04-15","lib_name":"양천"},{"class_no":"005.53","isbn13":"9791162245545","authors":"펠릭스 춤슈타인 지음 ;한선용 옮김","bookImageURL":"http://www.hello.world","bookname":"엑셀이 편해지는 파이썬 :엑셀 사용자를 위한 자동화 구축과 데이터 분석 ","publisher":"한빛미디어","reg_date":"2022-05-23","lib_name":"양천"},{"class_no":"005.133","isbn13":"9791163030287","authors":"다니엘 첸 (지은이), 김영하 (옮긴이)","bookImageURL":"http://www.hello.world","bookname":"Do it! 데이터 분석을 위한 판다스 입문","publisher":"이지스퍼블리싱","reg_date":"2019-06-17","lib_name":"양천"},{"class_no":"004.73","isbn13":"9791165211639","authors":"제임스 로이 지음 ;이춘오 옮김","bookImageURL":"http://www.hello.world","bookname":"신경망 교과서 :6개 프로젝트로 제대로 배우는 신경망의 기본기 ","publisher":"길벗","reg_date":"2020-06-11","lib_name":"양천"},{"class_no":"004.73","isb ...

# %%
request_object = resp.request

# Access properties of the request object
print(request_object.method)  # HTTP method used (e.g., GET, POST)
print(request_object.url)  # URL of the request
print(request_object.headers)  # Request headers
print(request_object.body)  # Request body (for POST requests)

# You can also print the full request object
print(request_object)
# Out:
# POST
# https://api.yangoos.me/predict
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Length': '67', 'Content-Type': 'application/json'}
# b'{"user_search": ["\\ub3c4\\ucee4"], "selected_lib": ["\\uc591\\ucc9c"]}'
# <PreparedRequest [POST]>

# %% [markdown]
# ### 새로운 기능 추가가 필요할 경우 pkl로 저장한 다음 노트북에서 만들자

# %%
import pickle
def _read_pkl( dir: str):
    with open(dir, "rb") as fp:
        data = pickle.load(fp)
        return data
set_isbn_in_selected_lib =_read_pkl("isbn_in_selected_lib")
data_1 =_read_pkl("../db/data/update/data_for_search")

# %%
pd.DataFrame(resp.json()['result'])
# Out:
#           publisher         isbn13    reg_date class_no  \
# 0             정보문화사  9788956748573  2020-12-01   004.73
# 1             한빛미디어  9791162240397  2018-01-29   004.73
# 2             가메출판사  9788980783113  2022-04-25   004.73
# 3                길벗  9791165218942  2022-04-25   004.73
# 4             한빛미디어  9791162242278  2019-11-12   004.73
# 5              생능출판  9788970503349  2021-01-08   004.73
# 6         Jpub(제이펍)  9791188621460  2019-04-02   004.73
# 7         Jpub(제이펍)  9791185890876  2018-08-20   004.73
# 8             한빛미디어  9791169210126  2023-01-12   004.73
# 9            비제이퍼블릭  9791165920753  2021-08-18   004.73
# 10          이지스퍼블리싱  9791163033165  2022-11-17  004.735
# 11            한빛미디어  9791162245415  2022-04-26   004.73
# 12            한빛미디어  9791162244876  2021-11-15   004.73
# 13            한빛미디어  9791162243596  2021-02-10   004.73
# 14            한빛미디어  9791162242964  2021-12-20   004.73
# 15            한빛미디어  9791162241974  2019-07-08   004.73
# 16            한빛미디어  9791162241899  2019-07-12   004.73
# 17            에이콘출판  9791161756523  2022-07-08   004.73
# 18            에이콘출판  9791161755892  2022-01-26   004.73
# 19              에이콘  9791161754925  2023-02-20   004.73
# 20            에이콘출판  9791161754321  2020-08-31   004.73
# 21              에이콘  9791161753966  2020-05-25   004.73
# 22             위키북스  9791158393007  2022-03-25  005.133
# 23             위키북스  9791158391713  2019-11-08    005.1
# 24             위키북스  9791158391225  2019-02-12   004.73
# 25               길벗  9791140700073  2022-08-08   004.73
# 26  AK(에이케이)커뮤니케이션즈  9791127455729  2023-01-12   004.73
# 27              光文閣  9788970939643  2020-02-05   004.73
# 28           비제이퍼블릭  9791190014755  2020-03-27   004.73
# 29              에이콘  9791161752006  2018-09-17   004.77
# 30            루비페이퍼  9791186710524  2019-09-04   004.73
# 31            루비페이퍼  9791186710807  2023-02-01   004.73
# 32           스포트라잇북  9791187431152  2018-09-17   004.73
#
#                                              bookname  \
# 0                                        파이썬 딥러닝 파이토치
# 1   (코딩셰프의) 3분 딥러닝 :케라스맛 :Keras 코드로 맛보는 ANN, DNN, ...
# 2                        OpenCV.Python 머신러닝 딥러닝 프로그래밍
# 3   딥러닝 파이토치 교과서 : 기초부터 CNN, RNN, 시계열 분석, 성능 최적화, ...
# 4                                 펭귄브로의 3분 딥러닝, 파이토치맛
# 5                                         처음 만나는 인공지능
# 6                                 케라스 창시자의 딥러닝 with R
# 7                                     텐서플로로 시작하는 딥러닝
# 8   개발자를 위한 머신러닝 & 딥러닝 - 인공지능 개발자로 레벨 업하기! 신경망 기초부...
# 9                     파이토치 딥러닝 프로젝트 모음집 :한 줄씩 따라 해보는
# 10  Do it! BERT와 GPT로 배우는 자연어 처리 - 트랜스포머 핵심 원리와 허깅...
# 11  케라스로 구현하는 딥러닝 :예제를 따라 하며 배우는 딥러닝 인공신경망 =In ten...
# 12  (한 권으로 다지는) 머신러닝&딥러닝 with 파이썬 :인공지능 핵심 개념과 사용 ...
# 13                                     밑바닥부터 시작하는 딥러닝
# 14  핸즈온 머신러닝 :사이킷런, 케라스, 텐서플로 2를 활용한 머신러닝, 딥러닝 완벽 실무
# 15  소문난 명강의 김기현의 자연어 처리 딥러닝 캠프 (파이토치 편,딥러닝 기반의 자연어...
# 16                                           파이토치 첫걸음
# 17  실무자를 위한 딥러닝(데이터 과학) (Practical Deep Learning: ...
# 18  텐서플로 2로 배우는 금융 머신러닝 :텐서플로와 Scikit-learn으로 금융 경...
# 19  자연어 처리와 딥러닝 - 딥러닝으로 바라보는 언어에 대한 생각, 2021년 대한민국...
# 20  핸즈온 머신러닝.딥러닝 알고리즘 트레이딩 :파이썬, Pandas, NumPy, Sc...
# 21           케라스 2.x 프로젝트 :실전 딥러닝 모델 구축과 훈련 9가지 프로젝트
# 22                                 파이썬 텍스트 마이닝 완벽 가이드
# 23                              케라스로 구현하는 고급 딥러닝 알고리즘
# 24  PyTorch를 활용한 머신러닝, 딥러닝 철저 입문 :파이토치를 활용한 머신러닝, ...
# 25                                            AI 상식사전
# 26  구글 코랩으로 배우는 인공지능 기술 - 머신러닝.딥러닝.강화 학습으로 배우는 AI의...
# 27                              (파이썬에 기반한) 케라스 딥러닝 실전
# 28                                  머신러닝을 위한 파이썬 한 조각
# 29                컴퓨터 비전과 딥러닝 :텐서플로와 케라스를 사용한 전문 가이드
# 30                      이토록 쉬운 딥러닝을 위한 기초수학 with 파이썬
# 31  플로우가 보이는 머신러닝 프로젝트 - 우아한 머신러닝을 위한 완벽한 데이터 분석 w...
# 32  딥다 딥러닝 =Hard training for deep learning :수학·이론...
#
#                             authors            bookImageURL lib_name
# 0                    이경택.방성수.안상준 지음  http://www.hello.world       강서
# 1                            김성진 지음  http://www.hello.world    양천 강서
# 2                               김동근  http://www.hello.world    양천 강서
# 3                            서지영 지음  http://www.hello.world       강서
# 4                        김건우.염상준 지음  http://www.hello.world    양천 강서
# 5                               김대수  http://www.hello.world    양천 양천
# 6      프랑소와 숄레.J. J. 알래어 지음, 박진수 옮김  http://www.hello.world    양천 강서
# 7                나카이 에츠지 지음 ;진명조 옮김  http://www.hello.world       양천
# 8                로런스 모로니 지음, 박해선 옮김  http://www.hello.world       양천
# 9                   투빅스,이경택 외 8인 지음  http://www.hello.world       양천
# 10                           이기창 지음  http://www.hello.world       강서
# 11                           김성진 지음  http://www.hello.world       강서
# 12    알베르토 아르타산체스,프라틱 조시 지음 ;여인춘 옮김  http://www.hello.world       양천
# 13           지은이: 사이토 고키 ;옮긴이: 개앞맵시  http://www.hello.world    양천 강서
# 14           지은이: 오렐리앙 제롱 ;옮긴이: 박해선  http://www.hello.world    양천 강서
# 15                       <b>김기현</b>  http://www.hello.world    양천 강서
# 16                           최건호 지음  http://www.hello.world       양천
# 17                          로널드 크누젤  http://www.hello.world       양천
# 18                 이사야 헐 지음 ;이병욱 옮김  http://www.hello.world    양천 강서
# 19              리 덩.양 리우 지음, 김재민 옮김  http://www.hello.world       강서
# 20           스테판 젠슨 지음 ;홍창수 ;이기홍 옮김  http://www.hello.world    양천 강서
# 21              주세페 시아부로 지음 ;김정중 옮김  http://www.hello.world       강서
# 22                   박상언.강주영.정석찬 지음  http://www.hello.world       강서
# 23                          로웰 아티엔자  http://www.hello.world       양천
# 24              코이즈미 사토시 지음 ;심효섭 옮김  http://www.hello.world       강서
# 25                           한규동 지음  http://www.hello.world       강서
# 26            아즈마 유키나가 지음, 김은철 외 옮김  http://www.hello.world       양천
# 27                      씨에량|루잉|라오훙란  http://www.hello.world       양천
# 28                           박성호 지음  http://www.hello.world       강서
# 29  라쟈링가파 샨무갸마니 지음 ;테크 트랜스 그룹 T4 옮김  http://www.hello.world       강서
# 30              마스이 도시카츠 지음 ;이중민 옮김  http://www.hello.world       강서
# 31                   임선집.채호창.곽랑주 지음  http://www.hello.world       양천
# 32                           양지헌 지음  http://www.hello.world       강서

# %%
data = pd.read_parquet('db/data/update/book_info.parquet')
payloads = data.iloc[:3].to_dict('list')
# payloads = dict(user_search=['파이썬'])
resp =requests.post("http://localhost:8000/update/book-info", json=payloads)

# %%
data = pd.read_parquet('db/data/lib_books.parquet') 
payloads = data.iloc[:3].to_dict('list')
# payloads = dict(user_search=['파이썬'])
resp =requests.post("http://localhost:8000/update/lib-books", json=payloads)

resp.text
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/yangwoolee/git_repo/dodomoa/App/ipynbfiles/request_test.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/dodomoa/App/ipynbfiles/request_test.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_parquet('db/data/lib_books.parquet')
#       <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/dodomoa/App/ipynbfiles/request_test.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> payloads = data.iloc[:3].to_dict('list')
#       <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/dodomoa/App/ipynbfiles/request_test.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # payloads = dict(user_search=['파이썬'])
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/io/parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     446 """
#     447 Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489 DataFrame
#     490 """
#     491 impl = get_engine(engine)
# --> 493 return impl.read(
#     494     path,
#     495     columns=columns,
#     496     storage_options=storage_options,
#     497     use_nullable_dtypes=use_nullable_dtypes,
#     498     **kwargs,
#     499 )
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/io/parquet.py:233, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     230 if manager == "array":
#     231     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 233 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     234     path,
#     235     kwargs.pop("filesystem", None),
#     236     storage_options=storage_options,
#     237     mode="rb",
#     238 )
#     239 try:
#     240     result = self.api.parquet.read_table(
#     241         path_or_handle, columns=columns, **kwargs
#     242     ).to_pandas(**to_pandas_kwargs)
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/io/parquet.py:102, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#      92 handles = None
#      93 if (
#      94     not fs
#      95     and not is_dir
#    (...)
#     100     # fsspec resources can also point to directories
#     101     # this branch is used for example when reading from non-fsspec URLs
# --> 102     handles = get_handle(
#     103         path_or_handle, mode, is_text=False, storage_options=storage_options
#     104     )
#     105     fs = None
#     106     path_or_handle = handles.handle
#
# File ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/io/common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'db/data/lib_books.parquet'
