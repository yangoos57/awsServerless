# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
df = spark.read.option("header",True).csv('./data/bookListSearch.csv',encoding='CP949')
df.show()
# Out:
# 22/07/15 16:16:24 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , 도서명, 저자, 출판사, ISBN, 주제분류번호, 등록일자
#  Schema: _c0, 도서명, 저자, 출판사, ISBN, 주제분류번호, 등록일자
# Expected: _c0 but found:
# CSV file: file:///Users/yangwoolee/git_repo/MLSpark/data/bookListSearch.csv
# +---+----------------------------------+-----------------------------------+--------------------------+-------------+------------+----------+
# |_c0|                            도서명|                               저자|                    출판사|         ISBN|주제분류번호|  등록일자|
# +---+----------------------------------+-----------------------------------+--------------------------+-------------+------------+----------+
# |  0|  (그림과 실습으로 배우는) 도커...|  오가사와라 시게타카 지음 ;심효...|                  위키북스|9791158393038|       005.1|2022-06-22|
# |  1| 도메인 주도 설계 첫걸음:소프트...|  블라드 코노노프 지음;김민석,오...|                  위키북스|9791158393359|     005.115|2022-06-22|
# |  2|   (눈 떠보니) 메타버스 마스터 ...|                 최재용,진성민 지음|                    光文閣|9788970936208|     004.783|2022-06-15|
# |  3|   혼자 공부하는 얄팍한 코딩 지식 |                        고현민 지음|                한빛미디어|9791162245552|      005.13|2022-06-15|
# |  4|        (Do it!) 점프 투 파이썬...|                        박응용 지음|            이지스퍼블리싱|9791163033554|     005.133|2022-06-15|
# |  5|   (한 권으로 끝내는) 메타버스 ...|                        주종민 지음|                  생능북스|9788970505411|     004.783|2022-06-15|
# |  6|     야사와 만화로 배우는 인공지능|     권건우,김가인,전준혁,허령 지음|              루나파인북스|9791197119927|      004.73|2022-06-15|
# |  7|   전길남, 연결의 탄생: 한국 인...|                        구본권 지음|                    김영사|9788934961772|      004.58|2022-06-07|
# |  8| 실무자를 위한 그래프 데이터 활...| 데니즈 고즈넬,마티아스 브뢰헬러...|                한빛미디어|9791162245590|      005.75|2022-06-07|
# |  9|   그림으로 이해하는 AWS 구조와...|  오가사와라 시게타카 지음 ;성창...|                      길벗|9791165215682|     004.588|2022-05-30|
# | 10|        그림으로 이해하는 인지과학|기타하라 요시노리 지음, 조태호 옮김|                      길벗|9791165219154|      004.73|2022-05-25|
# | 11|                객체지향 UI 디자인| 소시오미디어 주식회사.후지이 고...|                에이콘출판|9791161756240|      004.78|2022-05-25|
# | 12|                   오늘부터 개발자|                        김병욱 지음|                  천그루숲|9791188348909|       005.1|2022-05-25|
# | 13|             기계 학습을 다시 묻다|  레슬리 밸리언트 지음, 이광근 옮김|                  인사이트|9788966263264|      004.73|2022-05-25|
# | 14|어떻게 인간과 공존하는 인공지능...|    스튜어트 러셀 지음, 이한음 옮김|                    김영사|9788934988434|      004.73|2022-05-25|
# | 15| 비전공자도 이해할 수 있는 AI 지식|           박상길 지음, 정진호 그림|                      반니|9791167960221|      004.73|2022-05-25|
# | 16|      쉽게 배우는 AWS AI 서비스...|    피터 엘거,오언 셔너히 지음 ;...|                한빛미디어|9791162245521|      004.58|2022-05-23|
# | 17| 구글 엔지니어는 이렇게 일한다 ...|  타이터스 윈터스,톰 맨쉬렉,하이...|                한빛미디어|9791162245620|       005.1|2022-05-23|
# | 18|   (가장 쉬운 독학) 알고리즘 첫...|  마스이 도시카츠 지음;박광수(아...|        동양북스(동양문고)|9791157688050|     005.133|2022-05-23|
# | 19|    실전 알고리즘 트레이딩 배우기 | 세바스티앙 도나디오,수라브 고쉬...|에이콘(에이콘출판주식회사)|9791161754901|      004.73|2022-05-16|
# +---+----------------------------------+-----------------------------------+--------------------------+-------------+------------+----------+
# only showing top 20 rows
